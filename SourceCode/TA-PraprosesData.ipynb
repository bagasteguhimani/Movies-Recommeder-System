# %%
# !pip install demoji

# %%
import pandas as pd
from textblob import TextBlob
import re
# import demoji

# %%
https://drive.google.com/file/d/1_vP3GIdCcAKLrcfTaHshrr1XDWXiXAP5/view?usp=sharing
https://docs.google.com/spreadsheets/d/1JatR-CJLl8D5yZ2JDn1kEd0Yl_u9Fh39/edit?usp=sharing&ouid=116719699010307876833&rtpof=true&sd=true
# Out:
#   File "<ipython-input-8-88262e7fec75>", line 1
#     https://drive.google.com/file/d/1_vP3GIdCcAKLrcfTaHshrr1XDWXiXAP5/view?usp=sharing
#            ^
# SyntaxError: invalid syntax

# %%
# !gdown --id 1jv-d2GVB-iYcBrwVE4sxNyCo6B1dv59S
# !gdown --id 1pjJ-yRu1QY8z6wyQdwEnRZr4b4KHSmuc
# !gdown --id 1qxEIfR9u1vURcu3PrenetvQcbJp1fFYm
# !gdown --id 1LTCuV-YSfxqjTT_pSzzoIoyLzonqEFx1
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1qxEIfR9u1vURcu3PrenetvQcbJp1fFYm
# To: /content/data_tweet_pilih_ALL.csv
# 100% 898k/898k [00:00<00:00, 113MB/s]
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1LTCuV-YSfxqjTT_pSzzoIoyLzonqEFx1
# To: /content/data_tweet_pilih_ALL.xlsx
# 100% 474k/474k [00:00<00:00, 123MB/s]

# %%
df = pd.read_csv('Tweet_Full_Rfaldy.csv')

# %%
df

# %%
df_text = pd.DataFrame()
df_text['id_tweet'] = df['id_tweet']
df_text['text'] = df['Text']

# %%
df_text

# %%
## remove \n
df_text["text"] =  df_text["text"].str.replace("\n"," ")

# %%
## remove https
df_text['text'] = df_text['text'].str.replace(r'(?i)\s*\b(https).*', '')
## remove http
df_text['text'] = df_text['text'].str.replace(r'(?i)\s*\b(http).*', '')

# %%
##remove /mvs/
df_text['text'] = df_text['text'].str.replace('/mvs/', '')

# %%
# ##remove &amp
# df_text['text'] = df_text['text'].str.replace('&amp', '')

# %%
##remove mention & hashtag
def removeMentionHashtag(text) :
  temp = re.sub("@[A-Za-z0-9_]+","", text)
  temp = re.sub("#[A-Za-z0-9_]+","", temp)
  return temp

df_text['text'] = df_text['text'].apply(removeMentionHashtag)

# %%
##remove emoji
def remove_em(text):
  dem = demoji.findall(text)
  for item in dem.keys():
    text = text.replace(item, '')
  return text

df_text['text'] = df_text['text'].apply(remove_em)

# %%
df_text

# %%
df_text[df_text['id_tweet'] == 482063097016762368]['text'].to_list

# %%
tes = '(2010)'
tes
# Out:
# '(2010)'

# %%
data_text['text'].iloc[748]
# Out:
# '[review] (2010):'

# %%
## remove https
tes = tes.replace(r'(?i)\s*\b(https).*', '')
## remove http
tes = tes.replace(r'(?i)\s*\b(http).*', '')
tes
# Out:
# '[Movie] Cats &amp; Dogs : The Revenge of Kitty Galore (2010): http://wp.me/pV12u-8t = Dengan tema yang cukup klise dan cerita yang biasa saja, film ini tak menawarkan banyak, bahkan sebagai film sekuel tak ada sesuatu yang lebih menarik dari prekuelnya.'

# %%
tes = re.sub('[^A-Za-z0-9]+', ' ', tes)
tes
# Out:
# 'sequel of the year '

# %%
tes = re.sub("http://[A-Za-z0-9_]*","", tes)
tes

# %%
print(re.sub('@*', '', tes))

# %%
print(re.sub('@[A-Za-z0-9]*', '', tes))

# %%
print(re.sub('[a-z]*@', 'info@', str))

# %%
df['tweet'] = df['tweet'].str.replace(r'(?i)\s*\b(http).*', '')

# %%
print(re.sub('([a-z]*)@', '\1 19-@', tes))

# %%
temp = re.sub("@[A-Za-z0-9_]+","", tes)
temp = re.sub("#[A-Za-z0-9_]+","", temp)
temp

# %%
def Polarity(text):
    analysis = TextBlob(text)
    try:
        analysis = analysis.translate(from_lang='id',to="en")
        print(analysis)
    except Exception as e:
        print(e)
    return analysis.sentiment.polarity

# %%
df_text['Polarity'] = df_text['text'].apply(Polarity)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-9c955edc60e7> in <module>()
# ----> 1 df_text['Polarity'] = df_text['text'].apply(Polarity)
#
# NameError: name 'df_text' is not defined

# %%
Polarity(tes)
# Out:
# Translation API returned the input string unchanged.
# 0.0

# %%
anal = TextBlob(tes)
print(anal.sentiment.polarity)

# %%
&gt; &amp;

# %% [markdown]
# yg atas gausah diliat

# %% [markdown]
# DATASET PILIHAN

# %%
data_all = pd.read_excel('/content/data_tweet_pilih_ALL.xlsx')
data_all
# Out:
#       No Total     No            Nama               id_tweet     Username  \
# 0          1.0    1.0  Anang - data 6     134957482392035328   AnakNonton
# 1          2.0    2.0  Anang - data 6     815171905149804549   AnakNonton
# 2          3.0    3.0  Anang - data 6     289367304729395201   AnakNonton
# 3          4.0    4.0  Anang - data 6     136305227807723520   AnakNonton
# 4          5.0    5.0  Anang - data 6     546556697884385280   AnakNonton
# ...        ...    ...             ...                    ...          ...
# 3129    3130.0  157.0    Awi - Data 2  1382670000000000000.0  moviemenfes
# 3130    3131.0  158.0    Awi - Data 2  1238650000000000000.0  moviemenfes
# 3131    3132.0  159.0    Awi - Data 2  1223220000000000000.0  moviemenfes
# 3132    3133.0  160.0    Awi - Data 2  1395280000000000000.0  moviemenfes
# 3133    3134.0  161.0    Awi - Data 2  1359860000000000000.0  moviemenfes
#
#                            Date  \
# 0     2011-11-11 11:35:45+00:00
# ...

# %%
data_all_head = data_all.head(100).copy()

# %%
data_all_head
# Out:
#     No Total     No            Nama              id_tweet      Username  \
# 0        1.0    1.0  Anang - data 6    134957482392035328    AnakNonton
# 1        2.0    2.0  Anang - data 6    815171905149804549    AnakNonton
# 2        3.0    3.0  Anang - data 6    289367304729395201    AnakNonton
# 3        4.0    4.0  Anang - data 6    136305227807723520    AnakNonton
# 4        5.0    5.0  Anang - data 6    546556697884385280    AnakNonton
# ..       ...    ...             ...                   ...           ...
# 95      96.0   96.0  Anang - data 6  554000000000000000.0  danieldokter
# 96      97.0   97.0  Anang - data 6  293000000000000000.0  danieldokter
# 97      98.0   98.0  Anang - data 6  135000000000000000.0  danieldokter
# 98      99.0   99.0  Anang - data 6  323000000000000000.0  danieldokter
# 99     100.0  100.0  Anang - data 6  535000000000000000.0  danieldokter
#
#                          Date  \
# 0   2011-11-11 11:35:45+00:00
# 1   2016-12-31 12:25:02+00:00
# ...

# %%
data_text = pd.DataFrame()
data_text['id_tweet'] = data_all_head['id_tweet']
data_text['text'] = data_all_head['Text']
data_text['title'] = data_all_head['Title']
data_text
# Out:
#                 id_tweet                                               text  \
# 0     134957482392035328  [UPDATE] Wow! "Sang Pencerah", "Rumah Dara" da...
# 1     815171905149804549  #FilmTerbaik2016\n \n 5. 'Snowden' sekali lagi...
# 2     289367304729395201  #Oscars2013Nominations Animated Feature Film: ...
# 3     136305227807723520  [Top Ratings] "Real Steel" = pilihan masyaraka...
# 4     546556697884385280  #AnakNontonFunAward2014 Sequel of the Year | H...
# ..                   ...                                                ...
# 95  554000000000000000.0  ...and of course, makin' it felt so human. Mak...
# 96  293000000000000000.0  @fajryno1897 ha? Chernobyl diaries? 2 dari 5. ...
# 97  135000000000000000.0  Clash of the titans yg baru malah kacau mitolo...
# 98  323000000000000000.0  Top RT @ceciliarusli: Cloud Atlas: magical art...
# 99  535000000000000000.0  Indonesia itu moviegoers-nya keren2 lho. Cloud...
#
#                          title
# ...

# %%
data_text = pd.DataFrame()
data_text['id_tweet'] = data_all['id_tweet']
data_text['text'] = data_all['Text']
data_text['title'] = data_all['Title']
# data_text = data_text.iloc[748:848]
data_text
# Out:
#                    id_tweet  \
# 0        134957482392035328
# 1        815171905149804549
# 2        289367304729395201
# 3        136305227807723520
# 4        546556697884385280
# ...                     ...
# 3129  1382670000000000000.0
# 3130  1238650000000000000.0
# 3131  1223220000000000000.0
# 3132  1395280000000000000.0
# 3133  1359860000000000000.0
#
#                                                    text  \
# 0     [UPDATE] Wow! "Sang Pencerah", "Rumah Dara" da...
# 1     #FilmTerbaik2016\n \n 5. 'Snowden' sekali lagi...
# 2     #Oscars2013Nominations Animated Feature Film: ...
# 3     [Top Ratings] "Real Steel" = pilihan masyaraka...
# 4     #AnakNontonFunAward2014 Sequel of the Year | H...
# ...                                                 ...
# 3129  The Last Summer (2019) mvs\n \n "We should res...
# 3130  /mvs/ recomendd dongg film genre romance yg ke...
# 3131  /mvs/ ayo nonton TRIPLE FRONTIER, ada Oscar Is...
# ...

# %% [markdown]
# proses polarity

# %%
#remove enter & tab
data_text["text"] =  data_text["text"].str.replace("\n"," ").replace('\\t'," ").replace('\\t'," ")
data_text
# Out:
#                    id_tweet  \
# 0        134957482392035328
# 1        815171905149804549
# 2        289367304729395201
# 3        136305227807723520
# 4        546556697884385280
# ...                     ...
# 3129  1382670000000000000.0
# 3130  1238650000000000000.0
# 3131  1223220000000000000.0
# 3132  1395280000000000000.0
# 3133  1359860000000000000.0
#
#                                                    text  \
# 0     [UPDATE] Wow! "Sang Pencerah", "Rumah Dara" da...
# 1     #FilmTerbaik2016    5. 'Snowden' sekali lagi m...
# 2     #Oscars2013Nominations Animated Feature Film: ...
# 3     [Top Ratings] "Real Steel" = pilihan masyaraka...
# 4     #AnakNontonFunAward2014 Sequel of the Year | H...
# ...                                                 ...
# 3129  The Last Summer (2019) mvs    "We should respe...
# 3130  /mvs/ recomendd dongg film genre romance yg ke...
# 3131  /mvs/ ayo nonton TRIPLE FRONTIER, ada Oscar Is...
# ...

# %%
#remove https http
data_text['text']= data_text['text'].str.replace('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', ' ')
data_text
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#                    id_tweet  \
# 0        134957482392035328
# 1        815171905149804549
# 2        289367304729395201
# 3        136305227807723520
# 4        546556697884385280
# ...                     ...
# 3129  1382670000000000000.0
# 3130  1238650000000000000.0
# 3131  1223220000000000000.0
# 3132  1395280000000000000.0
# 3133  1359860000000000000.0
#
#                                                    text  \
# 0     [UPDATE] Wow! "Sang Pencerah", "Rumah Dara" da...
# 1     #FilmTerbaik2016    5. 'Snowden' sekali lagi m...
# 2     #Oscars2013Nominations Animated Feature Film: ...
# 3     [Top Ratings] "Real Steel" = pilihan masyaraka...
# 4     #AnakNontonFunAward2014 Sequel of the Year | H...
# ...                                                 ...
# 3129  The Last Summer (2019) mvs    "We should respe...
# ...

# %%
# ## remove https
# data_text['text'] = data_text['text'].str.replace(r'(?i)\s*\b(https).*', '')
# ## remove http
# data_text['text'] = data_text['text'].str.replace(r'(?i)\s*\b(http).*', '')
# data_text

# %%
#remove mention & hashtag
def removeMentionHashtag(text) :
  temp = re.sub("@[A-Za-z0-9_]+","", text)
  temp = re.sub("#[A-Za-z0-9_]+","", temp)
  return temp

data_text['text'] = data_text['text'].apply(removeMentionHashtag)
data_text
# Out:
#                    id_tweet  \
# 0        134957482392035328
# 1        815171905149804549
# 2        289367304729395201
# 3        136305227807723520
# 4        546556697884385280
# ...                     ...
# 3129  1382670000000000000.0
# 3130  1238650000000000000.0
# 3131  1223220000000000000.0
# 3132  1395280000000000000.0
# 3133  1359860000000000000.0
#
#                                                    text  \
# 0     [UPDATE] Wow! "Sang Pencerah", "Rumah Dara" da...
# 1         5. 'Snowden' sekali lagi membuktikan kalau...
# 2      Animated Feature Film: Frankenweeinie, The Pi...
# 3     [Top Ratings] "Real Steel" = pilihan masyaraka...
# 4      Sequel of the Year | How to Train Your Dragon...
# ...                                                 ...
# 3129  The Last Summer (2019) mvs    "We should respe...
# 3130  /mvs/ recomendd dongg film genre romance yg ke...
# 3131  /mvs/ ayo nonton TRIPLE FRONTIER, ada Oscar Is...
# ...

# %%
#remove /mvs/
data_text['text'] = data_text['text'].str.replace('/mvs/', '')
data_text['text'] = data_text['text'].str.replace('mvs', '')

data_text
# Out:
#                    id_tweet  \
# 0        134957482392035328
# 1        815171905149804549
# 2        289367304729395201
# 3        136305227807723520
# 4        546556697884385280
# ...                     ...
# 3129  1382670000000000000.0
# 3130  1238650000000000000.0
# 3131  1223220000000000000.0
# 3132  1395280000000000000.0
# 3133  1359860000000000000.0
#
#                                                    text  \
# 0     [UPDATE] Wow! "Sang Pencerah", "Rumah Dara" da...
# 1         5. 'Snowden' sekali lagi membuktikan kalau...
# 2      Animated Feature Film: Frankenweeinie, The Pi...
# 3     [Top Ratings] "Real Steel" = pilihan masyaraka...
# 4      Sequel of the Year | How to Train Your Dragon...
# ...                                                 ...
# 3129  The Last Summer (2019)     "We should respect ...
# 3130   recomendd dongg film genre romance yg kek to ...
# 3131   ayo nonton TRIPLE FRONTIER, ada Oscar Isaac, ...
# ...

# %%
#remove http symbol
def removeHTPPsymbol(text) :
  temp = re.sub("&[A-Za-z0-9_]+;","", text)
  # temp = re.sub("&[A-Za-z0-9_];","", text)

  return temp

data_text['text'] = data_text['text'].apply(removeHTPPsymbol)
data_text
# Out:
#                    id_tweet  \
# 0        134957482392035328
# 1        815171905149804549
# 2        289367304729395201
# 3        136305227807723520
# 4        546556697884385280
# ...                     ...
# 3129  1382670000000000000.0
# 3130  1238650000000000000.0
# 3131  1223220000000000000.0
# 3132  1395280000000000000.0
# 3133  1359860000000000000.0
#
#                                                    text  \
# 0     [UPDATE] Wow! "Sang Pencerah", "Rumah Dara" da...
# 1         5. 'Snowden' sekali lagi membuktikan kalau...
# 2      Animated Feature Film: Frankenweeinie, The Pi...
# 3     [Top Ratings] "Real Steel" = pilihan masyaraka...
# 4      Sequel of the Year | How to Train Your Dragon...
# ...                                                 ...
# 3129  The Last Summer (2019)     "We should respect ...
# 3130   recomendd dongg film genre romance yg kek to ...
# 3131   ayo nonton TRIPLE FRONTIER, ada Oscar Isaac, ...
# ...

# %%
# df = pd.read_excel('df_with_rating.xlsx')
# df
#ganti lowercase dan ganti tipe ke string
for i in range(len(data_text)):
    data_text["text"].iloc[i]=str(data_text["text"].iloc[i])
    data_text["text"].iloc[i]=data_text["text"].iloc[i].lower()
    data_text["title"].iloc[i]=str(data_text["title"].iloc[i])
    data_text["title"].iloc[i]=data_text["title"].iloc[i].lower()
data_text
#remove judul dari tweet
for i in range(len(data_text)):
    data_text["text"].iloc[i]=data_text["text"].iloc[i].replace(data_text["title"].iloc[i], "")
data_text
# Out:
#                    id_tweet  \
# 0        134957482392035328
# 1        815171905149804549
# 2        289367304729395201
# 3        136305227807723520
# 4        546556697884385280
# ...                     ...
# 3129  1382670000000000000.0
# 3130  1238650000000000000.0
# 3131  1223220000000000000.0
# 3132  1395280000000000000.0
# 3133  1359860000000000000.0
#
#                                                    text  \
# 0     [update] wow! "sang pencerah", "rumah dara" da...
# 1         5. '' sekali lagi membuktikan kalau oliver...
# 2      animated feature film: frankenweeinie, the pi...
# 3     [top ratings] "" = pilihan masyarakat! 4.2 of ...
# 4                               sequel of the year |
# ...                                                 ...
# 3129   (2019)     "we should respect each other when...
# 3130   recomendd dongg film genre romance yg kek to ...
# 3131   ayo nonton , ada oscar isaac, pedro pascal, b...
# ...

# %%
#remove special character
def removeSpecialChar(text) :
  return re.sub('[^A-Za-z0-9]+', ' ', text)

data_text['text'] = data_text['text'].apply(removeSpecialChar)
data_text
# Out:
#                    id_tweet  \
# 0        134957482392035328
# 1        815171905149804549
# 2        289367304729395201
# 3        136305227807723520
# 4        546556697884385280
# ...                     ...
# 3129  1382670000000000000.0
# 3130  1238650000000000000.0
# 3131  1223220000000000000.0
# 3132  1395280000000000000.0
# 3133  1359860000000000000.0
#
#                                                    text  \
# 0      update wow sang pencerah rumah dara dan masuk...
# 1      5 sekali lagi membuktikan kalau oliver stone ...
# 2      animated feature film frankenweeinie the pira...
# 3      top ratings pilihan masyarakat 4 2 of 5 stars...
# 4                                   sequel of the year
# ...                                                 ...
# 3129   2019 we should respect each other when we re ...
# 3130   recomendd dongg film genre romance yg kek to ...
# 3131   ayo nonton ada oscar isaac pedro pascal ben a...
# ...

# %%
#remove multiple space
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)
    
data_text['text'] = data_text['text'].apply(remove_whitespace_multiple)
data_text
# Out:
#                    id_tweet  \
# 0        134957482392035328
# 1        815171905149804549
# 2        289367304729395201
# 3        136305227807723520
# 4        546556697884385280
# ...                     ...
# 3129  1382670000000000000.0
# 3130  1238650000000000000.0
# 3131  1223220000000000000.0
# 3132  1395280000000000000.0
# 3133  1359860000000000000.0
#
#                                                    text  \
# 0      update wow sang pencerah rumah dara dan masuk...
# 1      5 sekali lagi membuktikan kalau oliver stone ...
# 2      animated feature film frankenweeinie the pira...
# 3      top ratings pilihan masyarakat 4 2 of 5 stars...
# 4                                   sequel of the year
# ...                                                 ...
# 3129   2019 we should respect each other when we re ...
# 3130   recomendd dongg film genre romance yg kek to ...
# 3131   ayo nonton ada oscar isaac pedro pascal ben a...
# ...

# %%
data_text['text'].iloc[748]
# Out:
# ' review 2010 impresi awal dari film ini adalah warna yang teduh dan penggambaran yang jelas tentang sebuah kehancuran dunia '

# %%
# def removeAll(text):
#   #remove enter & tab
#   text =  text.replace("\n"," ").replace('\\t'," ").replace('\t'," ")
#   # remove https
#   text = text.replace(r'(?i)\s*\b(https).*', '')
#   # remove http
#   text = text.replace(r'(?i)\s*\b(http).*', '')
#   return text

# %%
# # Mengubah menjadi String
# data_all['text'] = data_all['text'].astype(str)
# data_all['text'] = data_all['text'].apply(removeAll)

# %%
data_text
# Out:
#                    id_tweet  \
# 0        134957482392035328
# 1        815171905149804549
# 2        289367304729395201
# 3        136305227807723520
# 4        546556697884385280
# ...                     ...
# 3129  1382670000000000000.0
# 3130  1238650000000000000.0
# 3131  1223220000000000000.0
# 3132  1395280000000000000.0
# 3133  1359860000000000000.0
#
#                                                    text  \
# 0      update wow sang pencerah rumah dara dan masuk...
# 1      5 sekali lagi membuktikan kalau oliver stone ...
# 2      animated feature film frankenweeinie the pira...
# 3      top ratings pilihan masyarakat 4 2 of 5 stars...
# 4                                   sequel of the year
# ...                                                 ...
# 3129   2019 we should respect each other when we re ...
# 3130   recomendd dongg film genre romance yg kek to ...
# 3131   ayo nonton ada oscar isaac pedro pascal ben a...
# ...

# %%
data_text['text'].iloc[2]
# Out:
# ' animated feature film frankenweeinie the pirates band of misfits wreck it ralph brave '

# %%
data_text['Polarity'] = data_text['text'].apply(Polarity)
# Out:
# Update wow the enlightenment of Dara's house and enter the top ratings check here
# 5 Again proves that Oliver Stone is a biopic maestony
# Translation API returned the input string unchanged.
# Top Rating of Community Choice 4 2 of 5 Stars 79 Voters
# Translation API returned the input string unchanged.
# Review is so entertaining amazing in 3d got 5 5 stars from us
# Review of Mr. Peabody Sherman Beautiful and full of knowledge of knowledge
# Andi Novianto's best visual effects
# Rating Gets 5 5 Stars at 1 votes lead the top ratings list
# 1 Apart from the extraordinary exciting ending successful make a sobbing cry
# This means war 3 5 5 2 3 5
# Saga Breaking Dawn 1 can only be 2 stars from children watching in Indonesia, not much different from the Rotentomatoes IMDB Sweet review
# icymi after the incident wrong called the winner was named Oscar's best film
# Denzel Washington Always Looks Cool and Cold Agree
# ...

# %%
data_text
# Out:
#                    id_tweet  \
# 0        134957482392035328
# 1        815171905149804549
# 2        289367304729395201
# 3        136305227807723520
# 4        546556697884385280
# ...                     ...
# 3129  1382670000000000000.0
# 3130  1238650000000000000.0
# 3131  1223220000000000000.0
# 3132  1395280000000000000.0
# 3133  1359860000000000000.0
#
#                                                    text  \
# 0      update wow sang pencerah rumah dara dan masuk...
# 1      5 sekali lagi membuktikan kalau oliver stone ...
# 2      animated feature film frankenweeinie the pira...
# 3      top ratings pilihan masyarakat 4 2 of 5 stars...
# 4                                   sequel of the year
# ...                                                 ...
# 3129   2019 we should respect each other when we re ...
# 3130   recomendd dongg film genre romance yg kek to ...
# 3131   ayo nonton ada oscar isaac pedro pascal ben a...
# ...

# %%
data_text['rating'] = 0

# %%
data_text
# Out:
#                    id_tweet  \
# 0        134957482392035328
# 1        815171905149804549
# 2        289367304729395201
# 3        136305227807723520
# 4        546556697884385280
# ...                     ...
# 3129  1382670000000000000.0
# 3130  1238650000000000000.0
# 3131  1223220000000000000.0
# 3132  1395280000000000000.0
# 3133  1359860000000000000.0
#
#                                                    text  \
# 0      update wow sang pencerah rumah dara dan masuk...
# 1      5 sekali lagi membuktikan kalau oliver stone ...
# 2      animated feature film frankenweeinie the pira...
# 3      top ratings pilihan masyarakat 4 2 of 5 stars...
# 4                                   sequel of the year
# ...                                                 ...
# 3129   2019 we should respect each other when we re ...
# 3130   recomendd dongg film genre romance yg kek to ...
# 3131   ayo nonton ada oscar isaac pedro pascal ben a...
# ...

# %%
#rating
for i in range(len(data_text)):
    data_text["rating"].iloc[i]=(((data_text["Polarity"].iloc[i]+1)/2)*5)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
data_text
# Out:
#                    id_tweet  \
# 0        134957482392035328
# 1        815171905149804549
# 2        289367304729395201
# 3        136305227807723520
# 4        546556697884385280
# ...                     ...
# 3129  1382670000000000000.0
# 3130  1238650000000000000.0
# 3131  1223220000000000000.0
# 3132  1395280000000000000.0
# 3133  1359860000000000000.0
#
#                                                    text  \
# 0      update wow sang pencerah rumah dara dan masuk...
# 1      5 sekali lagi membuktikan kalau oliver stone ...
# 2      animated feature film frankenweeinie the pira...
# 3      top ratings pilihan masyarakat 4 2 of 5 stars...
# 4                                   sequel of the year
# ...                                                 ...
# 3129   2019 we should respect each other when we re ...
# 3130   recomendd dongg film genre romance yg kek to ...
# 3131   ayo nonton ada oscar isaac pedro pascal ben a...
# ...

# %%
data_text.to_excel('data_polarrating.xlsx')

# %% [markdown]
# ====================

# %%
# def remove_text_special(text):
#     ## remove https
#     text = text.replace(r'(?i)\s*\b(https).*', '')
#     ## remove http
#     text = text.replace(r'(?i)\s*\b(http).*', '')

#     # # menghapus tab, new line, ans back slice
#     # text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"").replace('/', '').replace('%', '').replace(',',' ').replace('(',' ').replace(')',' ').replace('"',' ')
#     # # menghapus non ASCII (emoticon, chinese word, .etc)
#     # text = text.encode('ascii', 'replace').decode('ascii')
#     # # menghapus mention, link, hashtag
#     # text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

#     # #menghapus html
#     # text = re.sub("&[A-Za-z0-9]*;","", text)
#     # #menghapus symbol
#     # text = re.sub(r'[^\w]', ' ', text)

#     # menghapus incomplete URL
#     # return text.replace("http://", " ").replace("https://", " ")
#     return text                
# batch1head['Text'] = batch1head['Text'].apply(remove_text_special)

# %%
# temp = '[UPDATE] Wow! Sang Pencerah Rumah Dara dan Tanda Tanya ? masuk Top Ratings!!! Cek di sini &asdasdasdagt;     &gt; asade asade '
# temp = re.sub("&[A-Za-z0-9]+;","", temp)
# temp

# %%
df_rate = pd.read_excel('/content/df_with_rating.xlsx')
df_rate

# %%
df_rate[df_rate['rating']<=0.5]
